# %%
def hex():
    while True:
        hex_string = input('enter a hex number:')
        
        if hex_string == '':
            print ('siktir')
            break
        
        print(f'your input:{hex_string}')
        
        dec_value = 0
        valid_input = True
        
        for power , digit in enumerate(reversed(hex_string)):
        
            if '0' <= digit <= '9':
                num = int(digit)
            elif 'a' <= digit.lower() <= 'f':
                num = ord(digit.lower()) -87
            else:
                print('invalid hex digit !')
                valid_input = False
                break
                dec_value +=num*(16**power)
                
            if valid_input:
                print(f'decimal valiue: {dec_value}')
                
            
hex()
# Out:
# your input:25f
# decimal valiue: 0
# decimal valiue: 0
# decimal valiue: 0
# your input:14f
# decimal valiue: 0
# decimal valiue: 0
# decimal valiue: 0
# your input:26
# decimal valiue: 0
# decimal valiue: 0
# your input:3265
# decimal valiue: 0
# decimal valiue: 0
# decimal valiue: 0
# decimal valiue: 0
# siktir
