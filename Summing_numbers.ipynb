# %%
#Sum_number
def Sum_number():
    total = 0
    while True:
        user = input('Enter a number:')
        
        if user == '':
            break
        
        total += int(user)
        print(total)
    
Sum_number()

# %%
#Sum_number
def Sum_number():
    numbers = []
    while True:
        user = input('Enter a number:')
        
        if user == '':
            break
        
        numbers.append(int(user))
        print(sum(numbers))
    
Sum_number()

# %%
#Sum_number_Advanced
def sum_advanced():
    total = 0
    count = 0
    largest = None
    smallest = None
    while True:
        user = input('enter number:')
        if user == '':
            break
        try:
            number = int(user)
        except ValueError:
            print('invalid input')
            continue
        total += number
        count +=1
        if largest is  None or number > largest:
            largest = number
        if smallest is None or number < smallest:
            smallest = number
        if count == 0:
            print('No numbers entered')
            return
        average = total / count
        
        print('Total:', total)
        print('Count:', count)
        print('Average:', average)
        print('Largest:', largest)
        print('Smallest:', smallest)
sum_advanced()
# Out:
# Total: 20
# Count: 1
# Average: 20.0
# Largest: 20
# Smallest: 20
# Total: 30
# Count: 2
# Average: 15.0
# Largest: 20
# Smallest: 10
# Total: 50
# Count: 3
# Average: 16.666666666666668
# Largest: 20
# Smallest: 10
# Total: 70
# Count: 4
# Average: 17.5
# Largest: 20
# Smallest: 10
# Total: 90
# Count: 5
# Average: 18.0
# Largest: 20
# Smallest: 10
# Total: 110
# Count: 6
# Average: 18.333333333333332
# Largest: 20
# Smallest: 10
# Total: 130
# Count: 7
# Average: 18.571428571428573
# Largest: 20
# Smallest: 10
# Total: 150
# Count: 8
# Average: 18.75
# Largest: 20
# Smallest: 10
# Total: 170
# Count: 9
# Average: 18.88888888888889
# Largest: 20
# Smallest: 10
# Total: 190
# Count: 10
# Average: 19.0
# Largest: 20
# Smallest: 10
# Total: 210
# Count: 11
# Average: 19.09090909090909
# Largest: 20
# Smallest: 10
# Total: 230
# Count: 12
# Average: 19.166666666666668
# Largest: 20
# Smallest: 10
# Total: 250
# Count: 13
# Average: 19.23076923076923
# Largest: 20
# Smallest: 10
# Total: 255
# Count: 14
# Average: 18.214285714285715
# Largest: 20
# Smallest: 5
# Total: 256
# Count: 15
# Average: 17.066666666666666
# Largest: 20
# Smallest: 1
# Total: 258
# Count: 16
# Average: 16.125
# Largest: 20
# Smallest: 1
# Total: 258
# Count: 17
# Average: 15.176470588235293
# Largest: 20
# Smallest: 0
