# %%
class person:
    count = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        person.count = person.count +1
    def get_name(self):
        print(f'name is {self.name}')
    def get_age(self):
        print(f'age is {self.age}')
    def get_info(self):
        print(f'name is {self.name} and age is {self.age}')
    def birthday(self):
        self.age = self.age + 1
        print(f'Happy Birthday {self.name}')
    def return_count(self):
        return(person.count)
    
print(f'at the moment i have {person.count}')
# Out:
# at the moment i have 0

# %%
em = person('emad', 12)
al = person('ali', 23)

em.return_count()
al.return_count()
# Out:
# 4

# %%
def
